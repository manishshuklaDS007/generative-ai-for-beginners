# %% [markdown]
# <a href="https://colab.research.google.com/github/manishshuklaDS007/generative-ai-for-beginners/blob/main/Data_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 🎉 Welcome to today's session! We’ll be diving into an exciting hands-on experience with data visualization. I hope everyone is as thrilled as I am! 🚀
#
# We’ll kick off in just a few minutes to allow others to join. Meanwhile, feel free to revise the basics of data visualization or do some quick hands-on practice to warm up. 🖌️📊
#
# I encourage everyone to be interactive during the session. If you have any questions or doubts, don’t hesitate to drop them in the chat box 💬✨. Let’s make this a fun and engaging learning experience! 🎯

# %%
# matplotlib
# seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#scatterplot -- compare and check relation b/w two numerical variables
#lineplot---trends
#barplot----cat vs numerical
#histplot---data distribution
#boxplot---outliers
#violin plot---density
#pair plot---relationship
#heatmap---multi variables correlation

# %%
df = sns.load_dataset('iris')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
#scatterplot---when you want compare two numerical variables and check the relation
sns.scatterplot(x='sepal_length',y='sepal_width',hue = 'species', data = df)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
#line plot

# %%
sns.lineplot(x='sepal_length',y='sepal_width',data = df)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
#barplot
sns.barplot(x ='species',y ='petal_length',palette= 'pastel',data=df)
# Out:
# <ipython-input-99-5b39f9fbe0fc>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x ='species',y ='petal_length',palette= 'pastel',data=df)
# <Axes: xlabel='species', ylabel='petal_length'>

# %%
#boxplot
plt.figure(figsize=(20,18))
sns.boxplot(x='sepal_length',y='sepal_width',data=df)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
#violin plot
sns.violinplot(x='species',y='sepal_width',data=df,palette='deep')
# Out:
# <ipython-input-101-1c5fd269ca81>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='species',y='sepal_width',data=df,palette='deep')
# <Axes: xlabel='species', ylabel='sepal_width'>

# %%
#pairplot
sns.pairplot(df,hue ='species')

# %%
import pandas as pd

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df1 = df.select_dtypes(include = ['number'])

# %%
df1.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(df1.corr(),cmap ="coolwarm",annot = True)
# Out:
# <Axes: >

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-108-2f6f6606aa2c> in <cell line: 0>()
# ----> 1 df.corr()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   11047         cols = data.columns
#   11048         idx = cols.copy()
# > 11049         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11050
#   11051         if method == "pearson":
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1991         if dtype is not None:
#    1992             dtype = np.dtype(dtype)
# -> 1993         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994         if result.dtype is not dtype:
#    1995             result = np.asarray(result, dtype=dtype)
#
# ...

# %%
#histogram
sns.histplot(x='sepal_length',data = df,kde = True)
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
import seaborn as sns
df = sns.load_dataset('titanic')

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#scatterplot -- compare and check relation b/w two numerical variables
#lineplot---trends
#barplot----cat vs numerical
#histplot---data distribution
#boxplot---outliers
#violin plot---density
#pair plot---relationship
#heatmap---multi variables correlation

#hue

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

titanic = sns.load_dataset("titanic")

# 1. Scatterplot: Relationship between age and fare
sns.scatterplot(data=titanic, x='age', y='fare', hue='survived')
plt.title('Scatterplot: Age vs Fare')
plt.show()

# 2. Lineplot: Trend of fare over passenger class
sns.lineplot(data=titanic, x='class', y='fare', hue='survived', ci=None)
plt.title('Lineplot: Fare Trends across Passenger Classes')
plt.show()

# 3. Barplot: Survival rate by class
sns.barplot(data=titanic, x='class', y='survived', ci=None)
plt.title('Barplot: Survival Rate by Class')
plt.show()

# 4. Histogram: Age distribution
sns.histplot(titanic['age'], bins=10, kde=True)
plt.title('Histogram: Age Distribution')
plt.show()

# 5. Boxplot: Fare distribution by class
sns.boxplot(data=titanic, x='class', y='fare')
plt.title('Boxplot: Fare by Class')
plt.show()

# 6. Violin Plot: Age distribution by sex
sns.violinplot(data=titanic, x='sex', y='age', hue='survived')
# Out:
# <ipython-input-113-5091899d29a0>:13: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=titanic, x='class', y='fare', hue='survived', ci=None)
# <ipython-input-113-5091899d29a0>:18: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=titanic, x='class', y='survived', ci=None)
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.pairplot(df,hue ='sex')

# %%
plt.figure(figsize=(22,20))
sns.boxplot(x='age',y='fare', data =df )
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %% [markdown]
# # Task 1: Create scatter plots for the following data
# # a. Create scatter plots with between (mpg-hp, mpg-weight), and (hp-mpg, hp-time-to-60) with respect to each brand in the same plane

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/cars (1).csv")

# %%
df
# Out:
#       mpg  cylinders cubicinches   hp weightlbs  time-to-60  year     brand
# 0    14.0          8         350  165      4209          12  1972       US.
# 1    31.9          4          89   71      1925          14  1980   Europe.
# 2    17.0          8         302  140      3449          11  1971       US.
# 3    15.0          8         400  150      3761          10  1971       US.
# 4    30.5          4          98   63      2051          17  1978       US.
# ..    ...        ...         ...  ...       ...         ...   ...       ...
# 256  17.0          8         305  130      3840          15  1980       US.
# 257  36.1          4          91   60      1800          16  1979    Japan.
# 258  22.0          6         232  112      2835          15  1983       US.
# 259  18.0          6         232  100      3288          16  1972       US.
# 260  22.0          6         250  105      3353          15  1977       US.
#
# [261 rows x 8 columns]

# %%
# a. Create scatter plots with between  with respect to each brand in the same plane
(mpg-hp, mpg-weight), and (hp-mpg, hp-time-to-60)

# %%
plt.figure(figsize=(14,10))

# %%
#mpg vs hp
plt.subplot(2,2,1)
sns.scatterplot(data=df,x='hp',y='mpg',hue='brand')
plt.title("mpg vs hp")

#mpg-weight
plt.subplot(2,2,2)
sns.scatterplot(data=df,x='weightlbs',y='mpg',hue='brand')
plt.title("mpg-weight")

#hp-mpg
plt.subplot(2,2,3)
sns.scatterplot(data=df,x='mpg',y='hp',hue='brand')
plt.title("hp vs mpg")

#hp-time-to-60
plt.subplot(2,2,4)
sns.scatterplot(data=df,x='hp',y='time-to-60',hue='brand')
plt.title("hp  vs time-to-60")

plt.tight_layout()
plt.show()

# %% [markdown]
# Create box plots for mpg, hp, weight, time-to-60 vs cylinders and with respect to brand

# %%
plt.figure(figsize=(15, 10))
plt.subplot(2, 2, 1)
sns.boxplot(x='cylinders', y='mpg', hue='brand', data=df)
plt.title('MPG vs. Cylinders by Brand')
plt.subplot(2, 2, 2)
sns.boxplot(x='cylinders', y='hp', hue='brand', data=df)
plt.title('HP vs. Cylinders by Brand')
plt.subplot(2, 2, 3)
sns.boxplot(x='cylinders', y='weightlbs', hue='brand', data=df)
plt.title('Weight vs. Cylinders by Brand')
plt.subplot(2, 2, 4)
sns.boxplot(x='cylinders', y='time-to-60', hue='brand', data=df)
plt.title('Time-to-60 vs. Cylinders by Brand')
plt.tight_layout()
plt.show()
