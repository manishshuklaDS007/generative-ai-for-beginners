# %% [markdown]
# <a href="https://colab.research.google.com/github/manishshuklaDS007/generative-ai-for-beginners/blob/main/Copy_of_HR_Data_Analysis)by_Manish.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd # Pandas is an open-source Python library providing efficient, easy-to-use data structure and data analysis
import numpy as np  # NumPy is a package for scientific computing.
import matplotlib.pyplot as plt # Matplotlib is a Python library that is specially designed for the development of graphs, charts etc., in order to provide interactive data visualisation.
import seaborn as sns # Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.

# %%
#To upload files
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-81499b82-980b-4663-be1b-2487229a64d3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-81499b82-980b-4663-be1b-2487229a64d3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data=pd.read_csv('employees.csv') #To load the DataFrame

# %%
data #Check the data
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0                   0.38            0.53                 2              157
# 1                   0.80            0.86                 5              262
# 2                   0.11            0.88                 7              272
# 3                   0.37            0.52                 2              159
# 4                   0.41            0.50                 2              153
# ...                  ...             ...               ...              ...
# 14994               0.11            0.85                 7              275
# 14995               0.99            0.83                 4              274
# 14996               0.72            0.72                 4              175
# 14997               0.24            0.91                 5              177
# 14998               0.77            0.83                 6              271
#
# ...

# %%
data.head() #To check the first 5 records
# Out:
#    satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0               0.38            0.53                 2              157
# 1               0.80            0.86                 5              262
# 2               0.11            0.88                 7              272
# 3               0.37            0.52                 2              159
# 4               0.41            0.50                 2              153
#
#    timeSpent.company  workAccident  left  promotionInLast5years   dept  salary
# 0                  3             0     1                      0  sales     low
# 1                  6             0     1                      0  sales  medium
# 2                  4             0     1                      0  sales  medium
# 3                  3             0     1                      0  sales     low
# 4                  3             0     1                      0  sales     low

# %%
data.tail() #To check last first 5 records
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 14994               0.11            0.85                 7              275
# 14995               0.99            0.83                 4              274
# 14996               0.72            0.72                 4              175
# 14997               0.24            0.91                 5              177
# 14998               0.77            0.83                 6              271
#
#        timeSpent.company  workAccident  left  promotionInLast5years  \
# 14994                  4             0     1                      0
# 14995                  2             0     0                      0
# 14996                  4             0     0                      0
# 14997                  5             0     0                      0
# 14998                  3             0     0                      0
#
#             dept  salary
# 14994    support  medium
# 14995      sales     low
# ...

# %%
data.info() #to get complete info about DataSet
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfactoryLevel      14999 non-null  float64
#  1   lastEvaluation         14999 non-null  float64
#  2   numberOfProjects       14999 non-null  int64
#  3   avgMonthlyHours        14999 non-null  int64
#  4   timeSpent.company      14999 non-null  int64
#  5   workAccident           14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotionInLast5years  14999 non-null  int64
#  8   dept                   14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
data.describe() #to get statistical info, it's return numerical value only.
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# count       14999.000000    14999.000000      14999.000000     14999.000000
# mean            0.612834        0.716102          3.803054       201.050337
# std             0.248631        0.171169          1.232592        49.943099
# min             0.090000        0.360000          2.000000        96.000000
# 25%             0.440000        0.560000          3.000000       156.000000
# 50%             0.640000        0.720000          4.000000       200.000000
# 75%             0.820000        0.870000          5.000000       245.000000
# max             1.000000        1.000000          7.000000       310.000000
#
#        timeSpent_company  workAccident          left  promotionInLast5years
# count       14999.000000  14999.000000  14999.000000           14999.000000
# mean            3.498233      0.144610      0.238083               0.021268
# ...

# %%
data.rename(columns={"timeSpent.company":"timeSpent_company"},inplace=True)

# %%
data
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0                   0.38            0.53                 2              157
# 1                   0.80            0.86                 5              262
# 2                   0.11            0.88                 7              272
# 3                   0.37            0.52                 2              159
# 4                   0.41            0.50                 2              153
# ...                  ...             ...               ...              ...
# 14994               0.11            0.85                 7              275
# 14995               0.99            0.83                 4              274
# 14996               0.72            0.72                 4              175
# 14997               0.24            0.91                 5              177
# 14998               0.77            0.83                 6              271
#
# ...

# %%
data.count() #Count() is a Python built-in function that returns the number of times an object appears in a list
# Out:
# satisfactoryLevel        14999
# lastEvaluation           14999
# numberOfProjects         14999
# avgMonthlyHours          14999
# timeSpent_company        14999
# workAccident             14999
# left                     14999
# promotionInLast5years    14999
# dept                     14999
# salary                   14999
# dtype: int64

# %%
#null records-----> isnull(), isna() : The functions isna() and isnull() both are used to identify missing values like NaN, NaT or None. It returns a same-sized boolean object indicating missing or null values as True and False for all other values.

data.isnull()
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0                  False           False             False            False
# 1                  False           False             False            False
# 2                  False           False             False            False
# 3                  False           False             False            False
# 4                  False           False             False            False
# ...                  ...             ...               ...              ...
# 14994              False           False             False            False
# 14995              False           False             False            False
# 14996              False           False             False            False
# 14997              False           False             False            False
# 14998              False           False             False            False
#
# ...

# %%
data.isna()
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0                  False           False             False            False
# 1                  False           False             False            False
# 2                  False           False             False            False
# 3                  False           False             False            False
# 4                  False           False             False            False
# ...                  ...             ...               ...              ...
# 14994              False           False             False            False
# 14995              False           False             False            False
# 14996              False           False             False            False
# 14997              False           False             False            False
# 14998              False           False             False            False
#
# ...

# %%
#returns the number of missing values in the dataset
data.isnull().sum()
# Out:
# satisfactoryLevel        0
# lastEvaluation           0
# numberOfProjects         0
# avgMonthlyHours          0
# timeSpent_company        0
# workAccident             0
# left                     0
# promotionInLast5years    0
# dept                     0
# salary                   0
# dtype: int64

# %%
#check the duplicate records
data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 14994     True
# 14995    False
# 14996    False
# 14997    False
# 14998    False
# Length: 14999, dtype: bool

# %%
data.duplicated().sum()
# Out:
# 3008

# %%
# Selecting duplicate rows except first
# occurrence based on all columns
duplicate = data[data.duplicated()]

print("Duplicate Rows :")

# Print the resultant Dataframe
duplicate
# Out:
# Duplicate Rows :
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 263                 0.46            0.57                 2              139
# 877                 0.37            0.51                 2              127
# 974                 0.42            0.53                 2              142
# 1017                0.40            0.50                 2              127
# 1241                0.10            0.85                 6              266
# ...                  ...             ...               ...              ...
# 14985               0.95            0.84                 3              270
# 14987               0.37            0.45                 2              126
# 14988               0.43            0.57                 2              157
# 14993               0.61            0.89                 3              242
# 14994               0.11            0.85                 7              275
#
# ...

# %%
# removing the duplicate records

data.drop_duplicates(keep="first",inplace=True)

# %%
data.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-047ed65ff157> in <cell line: 1>()
# ----> 1 data.shape
#
# NameError: name 'data' is not defined

# %%
14999-11991
# Out:
# 3008

# %%
data
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0                   0.38            0.53                 2              157
# 1                   0.80            0.86                 5              262
# 2                   0.11            0.88                 7              272
# 3                   0.37            0.52                 2              159
# 4                   0.41            0.50                 2              153
# ...                  ...             ...               ...              ...
# 14994               0.11            0.85                 7              275
# 14995               0.99            0.83                 4              274
# 14996               0.72            0.72                 4              175
# 14997               0.24            0.91                 5              177
# 14998               0.77            0.83                 6              271
#
# ...

# %%
data.corr(numeric_only = True)
# Out:
#                        satisfactoryLevel  lastEvaluation  numberOfProjects  \
# satisfactoryLevel               1.000000        0.105021         -0.142970
# lastEvaluation                  0.105021        1.000000          0.349333
# numberOfProjects               -0.142970        0.349333          1.000000
# avgMonthlyHours                -0.020048        0.339742          0.417211
# timeSpent.company              -0.100866        0.131591          0.196786
# workAccident                    0.058697       -0.007104         -0.004741
# left                           -0.388375        0.006567          0.023787
# promotionInLast5years           0.025605       -0.008684         -0.006064
#
#                        avgMonthlyHours  timeSpent.company  workAccident  \
# satisfactoryLevel            -0.020048          -0.100866      0.058697
# lastEvaluation                0.339742           0.131591     -0.007104
# numberOfProjects              0.417211           0.196786     -0.004741
# ...

# %%
#heatmap
sns.heatmap(data.corr(numeric_only = True), annot = True)
# Out:
# <Axes: >

# %%
ftr = ["dept","salary","promotionInLast5years","workAccident","timeSpent.company","numberOfProjects"]

# %%
data.columns
# Out:
# Index(['satisfactoryLevel', 'lastEvaluation', 'numberOfProjects',
#        'avgMonthlyHours', 'timeSpent.company', 'workAccident', 'left',
#        'promotionInLast5years', 'dept', 'salary'],
#       dtype='object')

# %%
ftr
# Out:
# ['dept',
#  'salary',
#  'promotionInLast5years',
#  'workAccident',
#  'timeSpent.company',
#  'numberOfProjects']

# %%
# enumerate function

for i,j in enumerate(ftr):
  print(i,j)
# Out:
# 0 dept
# 1 salary
# 2 promotionInLast5years
# 3 workAccident
# 4 timeSpent.company
# 5 numberOfProjects

# %%
fig = plt.subplots(figsize=(12,12))    #creates a figure with specified size

for p,q in enumerate(ftr):     #p returns the index value and q returns the column name
  plt.subplot(3,2,p+1)
  plt.subplots_adjust(hspace=1)
  sns.countplot(x = q, data = data, hue="left")
  plt.xticks(rotation=90)
# Out:
# <ipython-input-17-3650a94aa8c0>:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(3,2,p+1)

# %%
#Conclusion:-

# 1) Employees with less number of projects as well as with more number of projects are leaving the org or serving the notice period.

# 2) Employees who has min 3 years and max 6 years exp are leaving the org or serving the notice period

# 3) Employees who have not got promotion in last 5 years are leaving the company.

# 4) employees getting low and medium salary are eaving the org or serving the notice period.
